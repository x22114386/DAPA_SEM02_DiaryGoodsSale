# %% [markdown]
# # Importing All the Necessary Libraries

# %%
# !pip install scikit-learn
# Out:
# Requirement already satisfied: scikit-learn in c:\users\ashly\anaconda3\lib\site-packages (1.0.2)
# Requirement already satisfied: numpy>=1.14.6 in c:\users\ashly\anaconda3\lib\site-packages (from scikit-learn) (1.21.6)
# Requirement already satisfied: scipy>=1.1.0 in c:\users\ashly\anaconda3\lib\site-packages (from scikit-learn) (1.9.1)
# Requirement already satisfied: joblib>=0.11 in c:\users\ashly\anaconda3\lib\site-packages (from scikit-learn) (1.1.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\ashly\anaconda3\lib\site-packages (from scikit-learn) (2.2.0)

# %%
# Import necessary libraries
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
from scipy.stats import zscore

# Import necessary libraries for model selection
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, classification_report
from sklearn.model_selection import cross_val_score, KFold
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import StackingRegressor, BaggingRegressor, AdaBoostRegressor, VotingRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.neighbors import KNeighborsRegressor
from sklearn.metrics import mean_squared_error
from sklearn.preprocessing import StandardScaler
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import OneHotEncoder
from sklearn import preprocessing
from sklearn.model_selection import GridSearchCV,RandomizedSearchCV
import warnings

# Filter the FutureWarning
warnings.filterwarnings("ignore", category=FutureWarning, module="sklearn")
warnings.simplefilter(action='ignore', category=DeprecationWarning)
import shap

# %%
# !pip install missingno
# Out:
# Requirement already satisfied: missingno in c:\users\ashly\anaconda3\lib\site-packages (0.5.2)
# Requirement already satisfied: numpy in c:\users\ashly\anaconda3\lib\site-packages (from missingno) (1.21.6)
# Requirement already satisfied: matplotlib in c:\users\ashly\anaconda3\lib\site-packages (from missingno) (3.5.2)
# Requirement already satisfied: scipy in c:\users\ashly\anaconda3\lib\site-packages (from missingno) (1.9.1)
# Requirement already satisfied: seaborn in c:\users\ashly\anaconda3\lib\site-packages (from missingno) (0.11.2)
# Requirement already satisfied: cycler>=0.10 in c:\users\ashly\anaconda3\lib\site-packages (from matplotlib->missingno) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\ashly\anaconda3\lib\site-packages (from matplotlib->missingno) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\ashly\anaconda3\lib\site-packages (from matplotlib->missingno) (1.4.2)
# Requirement already satisfied: packaging>=20.0 in c:\users\ashly\anaconda3\lib\site-packages (from matplotlib->missingno) (21.3)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\ashly\anaconda3\lib\site-packages (from matplotlib->missingno) (9.2.0)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\ashly\anaconda3\lib\site-packages (from matplotlib->missingno) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\ashly\anaconda3\lib\site-packages (from matplotlib->missingno) (2.8.2)
# Requirement already satisfied: pandas>=0.23 in c:\users\ashly\anaconda3\lib\site-packages (from seaborn->missingno) (1.4.4)
# Requirement already satisfied: pytz>=2020.1 in c:\users\ashly\anaconda3\lib\site-packages (from pandas>=0.23->seaborn->missingno) (2022.1)
# Requirement already satisfied: six>=1.5 in c:\users\ashly\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib->missingno) (1.16.0)

# %%
import missingno as msno

# %%
sns.set_theme(color_codes=True)
pd.set_option('display.max_columns', None)

# %% [markdown]
# # Data Extraction

# %%
dairy_df = pd.read_csv('dairy_dataset.csv')
dairy_df.head()
# Out:
#         Location  Total Land Area (acres)  Number of Cows Farm Size  \
# 0      Telangana                   310.84              96    Medium
# 1  Uttar Pradesh                    19.19              44     Large
# 2     Tamil Nadu                   581.69              24    Medium
# 3      Telangana                   908.00              89     Small
# 4    Maharashtra                   861.95              21    Medium
#
#          Date  Product ID Product Name                 Brand  \
# 0  2022-02-17           5    Ice Cream           Dodla Dairy
# 1  2021-12-01           1         Milk                  Amul
# 2  2022-02-28           4       Yogurt           Dodla Dairy
# 3  2019-06-09           3       Cheese  Britannia Industries
# 4  2020-12-14           8   Buttermilk          Mother Dairy
#
#    Quantity (liters/kg)  Price per Unit  Total Value  Shelf Life (days)  \
# 0                222.40           85.72   19064.1280                 25
# 1                687.48           42.61   29293.5228                 22
# 2                503.48           36.50   18377.0200                 30
# 3                823.36           26.52   21835.5072                 72
# 4                147.77           83.85   12390.5145                 11
#
#   Storage Condition Production Date Expiration Date  \
# 0            Frozen      2021-12-27      2022-01-21
# 1        Tetra Pack      2021-10-03      2021-10-25
# 2      Refrigerated      2022-01-14      2022-02-13
# 3            Frozen      2019-05-15      2019-07-26
# 4      Refrigerated      2020-10-17      2020-10-28
#
#    Quantity Sold (liters/kg)  Price per Unit (sold)  \
# 0                          7                  82.24
# 1                        558                  39.24
# 2                        256                  33.81
# 3                        601                  28.92
# 4                        145                  83.07
#
#    Approx. Total Revenue(INR) Customer Location Sales Channel  \
# 0                      575.68    Madhya Pradesh     Wholesale
# 1                    21895.92            Kerala     Wholesale
# 2                     8655.36    Madhya Pradesh        Online
# 3                    17380.92         Rajasthan        Online
# 4                    12045.15         Jharkhand        Retail
#
#    Quantity in Stock (liters/kg)  Minimum Stock Threshold (liters/kg)  \
# 0                            215                                19.55
# 1                            129                                43.17
# 2                            247                                15.10
# 3                            222                                74.50
# 4                              2                                76.02
#
#    Reorder Quantity (liters/kg)
# 0                         64.03
# 1                        181.10
# 2                        140.83
# 3                         57.68
# 4                         33.40

# %% [markdown]
# # Data Pre-Processing (Data Cleaning)

# %% [markdown]
# 01. Null Value Removals
# 02. Data Type Conversion
# 03. Convert 'date' column to datetime
# 04. Removing Outliers (example using z-score)
# 05. Standardizing and Normalizing Data
# 06. Handling Inconsistent Values
# 07. Data Formatting
# 08. Handling Encoding Issues (example using UTF-8 encoding)
# 09. Feature Engineering 'Total Revenue (INR)'= 'Quantity (liters/kg)' * df'Price per Unit'
# 10. Feature Engineering Data Validation (example checking minimum stock threshold)
# 11. Finally Display the cleaned dataset

# %%
# Check the number of unique value from all of the object data types
dairy_df.select_dtypes(include='object').nunique()
# Out:
# Location               15
# Farm Size               3
# Date                 1278
# Product Name           10
# Brand                  11
# Storage Condition       5
# Production Date      1405
# Expiration Date      1441
# Customer Location      15
# Sales Channel           3
# dtype: int64

# %%
# Check all the headers in the csv file 
headers = dairy_df.columns.tolist()
print(headers)
# Out:
# ['Location', 'Total Land Area (acres)', 'Number of Cows', 'Farm Size', 'Date', 'Product ID', 'Product Name', 'Brand', 'Quantity (liters/kg)', 'Price per Unit', 'Total Value', 'Shelf Life (days)', 'Storage Condition', 'Production Date', 'Expiration Date', 'Quantity Sold (liters/kg)', 'Price per Unit (sold)', 'Approx. Total Revenue(INR)', 'Customer Location', 'Sales Channel', 'Quantity in Stock (liters/kg)', 'Minimum Stock Threshold (liters/kg)', 'Reorder Quantity (liters/kg)']

# %%
# Check for null values
msno.matrix(dairy_df, sparkline=False, figsize=(10, 6), color=(0, 0, 0))
plt.xlabel('Columns')
plt.ylabel('Rows')
plt.title('Missing Data Pattern')
plt.show()
# There are no null values in the data
# No single column can determine duplicates when considering the recursive combination of 'Location', 'Date', 'Product ID', and 'Product Name'

# %%
# Data Type Conversion
dairy_df['Date'] = pd.to_datetime(dairy_df['Date'])  # Convert 'Date' column to datetime

# Convert 'date' column to datetime
dairy_df['Production Date'] = pd.to_datetime(dairy_df['Production Date'])

# Removing Outliers (example using z-score)
z_scores = (dairy_df['Quantity (liters/kg)'] - dairy_df['Quantity (liters/kg)'].mean()) / dairy_df['Quantity (liters/kg)'].std()
dairy_df = dairy_df[z_scores.abs() < 3]  # Remove rows with z-scores outside the threshold

# Standardizing and Normalizing Data
dairy_df['Quantity (liters/kg)'] = (dairy_df['Quantity (liters/kg)'] - dairy_df['Quantity (liters/kg)'].mean()) / dairy_df['Quantity (liters/kg)'].std()

# Handling Inconsistent Values
dairy_df['Location'] = dairy_df['Location'].str.strip()  # Remove leading/trailing white spaces

# Data Formatting
dairy_df['Product Name'] = dairy_df['Product Name'].str.title()  # Capitalize each word in 'Product Name'

# Handling Encoding Issues (example using UTF-8 encoding)
dairy_df['Product Name'] = dairy_df['Product Name'].str.encode('utf-8').str.decode('utf-8')

# Feature Engineering
dairy_df['Total Revenue (INR)'] = dairy_df['Quantity (liters/kg)'] * dairy_df['Price per Unit']

# Data Validation (example checking minimum stock threshold)
dairy_df = dairy_df[dairy_df['Quantity in Stock (liters/kg)'] >= dairy_df['Minimum Stock Threshold (liters/kg)']]

# Display the cleaned dataset
print(dairy_df.head())
# Out:
#         Location  Total Land Area (acres)  Number of Cows Farm Size  \
# 0      Telangana                   310.84              96    Medium
# 1  Uttar Pradesh                    19.19              44     Large
# 2     Tamil Nadu                   581.69              24    Medium
# 3      Telangana                   908.00              89     Small
# 5      Telangana                    87.64              51    Medium
#
#         Date  Product ID Product Name                 Brand  \
# 0 2022-02-17           5    Ice Cream           Dodla Dairy
# 1 2021-12-01           1         Milk                  Amul
# 2 2022-02-28           4       Yogurt           Dodla Dairy
# 3 2019-06-09           3       Cheese  Britannia Industries
# 5 2019-01-07           6         Curd                   Raj
#
#    Quantity (liters/kg)  Price per Unit  Total Value  Shelf Life (days)  \
# 0             -0.962892           85.72   19064.1280                 25
# 1              0.646515           42.61   29293.5228                 22
# 2              0.009784           36.50   18377.0200                 30
# 3              1.116727           26.52   21835.5072                 72
# 5              0.322751           85.54   50803.9168                  5
#
#   Storage Condition Production Date Expiration Date  \
# 0            Frozen      2021-12-27      2022-01-21
# 1        Tetra Pack      2021-10-03      2021-10-25
# 2      Refrigerated      2022-01-14      2022-02-13
# 3            Frozen      2019-05-15      2019-07-26
# 5      Refrigerated      2019-01-03      2019-01-08
#
#    Quantity Sold (liters/kg)  Price per Unit (sold)  \
# 0                          7                  82.24
# 1                        558                  39.24
# 2                        256                  33.81
# 3                        601                  28.92
# 5                         74                  84.75
#
#    Approx. Total Revenue(INR) Customer Location Sales Channel  \
# 0                      575.68    Madhya Pradesh     Wholesale
# 1                    21895.92            Kerala     Wholesale
# 2                     8655.36    Madhya Pradesh        Online
# 3                    17380.92         Rajasthan        Online
# 5                     6271.50           Gujarat        Retail
#
#    Quantity in Stock (liters/kg)  Minimum Stock Threshold (liters/kg)  \
# 0                            215                                19.55
# 1                            129                                43.17
# 2                            247                                15.10
# 3                            222                                74.50
# 5                            519                                55.60
#
#    Reorder Quantity (liters/kg)  Total Revenue (INR)
# 0                         64.03           -82.539120
# 1                        181.10            27.548016
# 2                        140.83             0.357116
# 3                         57.68            29.615613
# 5                        139.59            27.608144

# %%
# Removing Outliers using z-score
z_scores = (dairy_df['Quantity (liters/kg)'] - dairy_df['Quantity (liters/kg)'].mean()) / dairy_df['Quantity (liters/kg)'].std()
outliers = dairy_df[z_scores.abs() >= 3]  # Identify rows with z-scores outside the threshold

# Plotting the outliers
plt.scatter(dairy_df.index, dairy_df['Quantity (liters/kg)'], label='Data')
plt.scatter(outliers.index, outliers['Quantity (liters/kg)'], color='red', label='Outliers')
plt.xlabel('Index')
plt.ylabel('Quantity (liters/kg)')
plt.title('Outliers')
plt.legend()
plt.show()

# %%
dairy_df.head()
# Out:
#         Location  Total Land Area (acres)  Number of Cows Farm Size  \
# 0      Telangana                   310.84              96    Medium
# 1  Uttar Pradesh                    19.19              44     Large
# 2     Tamil Nadu                   581.69              24    Medium
# 3      Telangana                   908.00              89     Small
# 5      Telangana                    87.64              51    Medium
#
#         Date  Product ID Product Name                 Brand  \
# 0 2022-02-17           5    Ice Cream           Dodla Dairy
# 1 2021-12-01           1         Milk                  Amul
# 2 2022-02-28           4       Yogurt           Dodla Dairy
# 3 2019-06-09           3       Cheese  Britannia Industries
# 5 2019-01-07           6         Curd                   Raj
#
#    Quantity (liters/kg)  Price per Unit  Total Value  Shelf Life (days)  \
# 0             -0.962892           85.72   19064.1280                 25
# 1              0.646515           42.61   29293.5228                 22
# 2              0.009784           36.50   18377.0200                 30
# 3              1.116727           26.52   21835.5072                 72
# 5              0.322751           85.54   50803.9168                  5
#
#   Storage Condition Production Date Expiration Date  \
# 0            Frozen      2021-12-27      2022-01-21
# 1        Tetra Pack      2021-10-03      2021-10-25
# 2      Refrigerated      2022-01-14      2022-02-13
# 3            Frozen      2019-05-15      2019-07-26
# 5      Refrigerated      2019-01-03      2019-01-08
#
#    Quantity Sold (liters/kg)  Price per Unit (sold)  \
# 0                          7                  82.24
# 1                        558                  39.24
# 2                        256                  33.81
# 3                        601                  28.92
# 5                         74                  84.75
#
#    Approx. Total Revenue(INR) Customer Location Sales Channel  \
# 0                      575.68    Madhya Pradesh     Wholesale
# 1                    21895.92            Kerala     Wholesale
# 2                     8655.36    Madhya Pradesh        Online
# 3                    17380.92         Rajasthan        Online
# 5                     6271.50           Gujarat        Retail
#
#    Quantity in Stock (liters/kg)  Minimum Stock Threshold (liters/kg)  \
# 0                            215                                19.55
# 1                            129                                43.17
# 2                            247                                15.10
# 3                            222                                74.50
# 5                            519                                55.60
#
#    Reorder Quantity (liters/kg)  Total Revenue (INR)
# 0                         64.03           -82.539120
# 1                        181.10            27.548016
# 2                        140.83             0.357116
# 3                         57.68            29.615613
# 5                        139.59            27.608144

# %%
headers = dairy_df.columns.tolist()
print(headers)
# Out:
# ['Location', 'Total Land Area (acres)', 'Number of Cows', 'Farm Size', 'Date', 'Product ID', 'Product Name', 'Brand', 'Quantity (liters/kg)', 'Price per Unit', 'Total Value', 'Shelf Life (days)', 'Storage Condition', 'Production Date', 'Expiration Date', 'Quantity Sold (liters/kg)', 'Price per Unit (sold)', 'Approx. Total Revenue(INR)', 'Customer Location', 'Sales Channel', 'Quantity in Stock (liters/kg)', 'Minimum Stock Threshold (liters/kg)', 'Reorder Quantity (liters/kg)', 'Total Revenue (INR)']

# %% [markdown]
# # Label Encoding each Object datatypes

# %%
# Loop over each column in the DataFrame where dtype is 'object'
for col in dairy_df.select_dtypes(include=['object']).columns:

    # Print the column name and the unique values
    print(f"{col}: {dairy_df[col].unique()}")
# Out:
# Location: ['Telangana' 'Uttar Pradesh' 'Tamil Nadu' 'Karnataka' 'Bihar'
#  'West Bengal' 'Chandigarh' 'Gujarat' 'Madhya Pradesh' 'Kerala'
#  'Jharkhand' 'Maharashtra' 'Delhi' 'Rajasthan' 'Haryana']
# Farm Size: ['Medium' 'Large' 'Small']
# Product Name: ['Ice Cream' 'Milk' 'Yogurt' 'Cheese' 'Curd' 'Paneer' 'Buttermilk' 'Lassi'
#  'Ghee' 'Butter']
# Brand: ['Dodla Dairy' 'Amul' 'Britannia Industries' 'Raj' 'Dynamix Dairies'
#  'Mother Dairy' 'Sudha' 'Warana' 'Passion Cheese' 'Palle2patnam'
#  'Parag Milk Foods']
# Storage Condition: ['Frozen' 'Tetra Pack' 'Refrigerated' 'Ambient' 'Polythene Packet']
# Expiration Date: ['2022-01-21' '2021-10-25' '2022-02-13' ... '2020-03-13' '2020-01-08'
#  '2019-01-07']
# Customer Location: ['Madhya Pradesh' 'Kerala' 'Rajasthan' 'Gujarat' 'Karnataka' 'Haryana'
#  'Jharkhand' 'Tamil Nadu' 'West Bengal' 'Telangana' 'Chandigarh'
#  'Maharashtra' 'Delhi' 'Bihar' 'Uttar Pradesh']
# Sales Channel: ['Wholesale' 'Online' 'Retail']

# %%
# Loop over each column in the DataFrame where dtype is 'object'
for col in dairy_df.select_dtypes(include=['object']).columns:

    # Initialize a LabelEncoder object
    label_encoder = preprocessing.LabelEncoder()

    # Fit the encoder to the unique values in the column
    label_encoder.fit(dairy_df[col].unique())

    # Transform the column using the encoder
    dairy_df[col] = label_encoder.transform(dairy_df[col])

    # Print the column name and the unique encoded values
    print(f"{col}: {dairy_df[col].unique()}")
# Out:
# Location: [12 13 11  6  0 14  1  3  8  7  5  9  2 10  4]
# Farm Size: [1 0 2]
# Product Name: [5 7 9 2 3 8 1 6 4 0]
# Brand: [ 2  0  1  8  3  4  9 10  7  5  6]
# Storage Condition: [1 4 3 0 2]
# Expiration Date: [1028  948 1050 ...  412  354   23]
# Customer Location: [ 8  7 10  3  6  4  5 11 14 12  1  9  2  0 13]
# Sales Channel: [2 0 1]

# %% [markdown]
# # Exploratory Data Analysis

# %% [markdown]
# 1. Plotting the bar plot for the categorical variables vs the Reorder Quantity (liters/kg)
# - Location
# - Farm Size
# - Product Name
# - Brand
# - Storage Condition
# - Customer Location
# - Sales Channel

# %%
# List of categorical variables to plot
cat_vars = ['Location', 'Farm Size', 'Product Name',
            'Brand', 'Storage Condition', 'Customer Location',
            'Sales Channel']

# Create figure with subplots
fig, axs = plt.subplots(nrows=3, ncols=3, figsize=(20, 15))
axs = axs.flatten()

# Create barplot for each categorical variable
for i, var in enumerate(cat_vars):
    sns.barplot(x=var, y='Reorder Quantity (liters/kg)', data=dairy_df, ax=axs[i], estimator=np.mean)
    axs[i].set_xticklabels(axs[i].get_xticklabels(), rotation=90)

# Remove the eigth subplot
fig.delaxes(axs[7])

# Remove the ninth subplot
fig.delaxes(axs[8])

# Adjust spacing between subplots
fig.tight_layout()

# Show plot
plt.show()

# %% [markdown]
# 2. Plotting a pie chart to show the distribution of the categorical variables
# - Location
# - Farm Size
# - Product Name
# - Brand
# - Storage Condition
# - Customer Location
# - Sales Channel

# %%
# Specify the maximum number of categories to show individually
max_categories = 5

cat_vars = ['Location', 'Farm Size', 'Product Name',
            'Brand', 'Storage Condition', 'Customer Location',
            'Sales Channel']

# Create a figure and axes
fig, axs = plt.subplots(nrows=3, ncols=3, figsize=(15, 15))

# Create a pie chart for each categorical variable
for i, var in enumerate(cat_vars):
    if i < len(axs.flat):
        # Count the number of occurrences for each category
        cat_counts = dairy_df[var].value_counts()

        # Group categories beyond the top max_categories as 'Other'
        if len(cat_counts) > max_categories:
            cat_counts_top = cat_counts[:max_categories]
            cat_counts_other = pd.Series(cat_counts[max_categories:].sum(), index=['Other'])
            cat_counts = cat_counts_top.append(cat_counts_other)

        # Create a pie chart
        axs.flat[i].pie(cat_counts, labels=cat_counts.index, autopct='%1.1f%%', startangle=90)

        # Set a title for each subplot
        axs.flat[i].set_title(f'{var} Distribution')

# Adjust spacing between subplots
fig.tight_layout()

# Remove eigth plot
fig.delaxes(axs[2][1])

# Remove ninth plot
fig.delaxes(axs[2][2])

# Show the plot
plt.show()
# Out:
# The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.

# %% [markdown]
# 3. Plotting box plots for the numerical variables
# - Total Land Area (acres)
# - Number of Cows
# - Quantity (liters/kg)
# - Price per Unit
# - Total Value
# - Shelf Life (days)
# - Quantity Sold (liters/kg)
# - Price per Unit (sold)
# - Approx. Total Revenue(INR)
# - Quantity in Stock (liters/kg)
# - Minimum Stock Threshold (liters/kg)

# %%
# List of numerical variables to plot
num_vars = ['Total Land Area (acres)', 'Number of Cows', 'Quantity (liters/kg)', 'Price per Unit',
            'Total Value', 'Shelf Life (days)', 'Quantity Sold (liters/kg)', 'Price per Unit (sold)',
            'Approx. Total Revenue(INR)', 'Quantity in Stock (liters/kg)', 'Minimum Stock Threshold (liters/kg)']

# Create figure with subplots
fig, axs = plt.subplots(nrows=3, ncols=4, figsize=(20, 14))
axs = axs.flatten()

# Create violinplot for each numerical variable
for i, var in enumerate(num_vars):
    sns.boxplot(x=var, data=dairy_df, ax=axs[i])

# Adjust spacing between subplots
fig.tight_layout()

# Remove the 12th subplot
fig.delaxes(axs[11])

plt.show()

# %% [markdown]
# 4. Plotting violin plots for the numerical variables
# - Total Land Area (acres)
# - Number of Cows
# - Quantity (liters/kg)
# - Price per Unit
# - Total Value
# - Shelf Life (days)
# - Quantity Sold (liters/kg)
# - Price per Unit (sold)
# - Approx. Total Revenue(INR)
# - Quantity in Stock (liters/kg)
# - Minimum Stock Threshold (liters/kg)

# %%
# List of numerical variables to plot
num_vars = ['Total Land Area (acres)', 'Number of Cows', 'Quantity (liters/kg)', 'Price per Unit',
            'Total Value', 'Shelf Life (days)', 'Quantity Sold (liters/kg)', 'Price per Unit (sold)',
            'Approx. Total Revenue(INR)', 'Quantity in Stock (liters/kg)', 'Minimum Stock Threshold (liters/kg)']

# Create figure with subplots
fig, axs = plt.subplots(nrows=3, ncols=4, figsize=(20, 14))
axs = axs.flatten()

# Create violinplot for each numerical variable
for i, var in enumerate(num_vars):
    sns.violinplot(x=var, data=dairy_df, ax=axs[i])

# Adjust spacing between subplots
fig.tight_layout()

# Remove the 12th subplot
fig.delaxes(axs[11])

plt.show()

# %% [markdown]
# 05. Correlation Heatmap

# %%
# Correlation Heatmap
plt.figure(figsize=(20, 16))
sns.heatmap(dairy_df.corr(), fmt='.2g', annot=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# 6. Plotting scatter plot for two numerical variables
#  - price per unit sold Vs Price per unit
#  - Scatter Plot of Quantity vs. Approx. Total Revenue'

# %%
# Calculate correlation with 'Price per Unit'
correlation = dairy_df.corr()['Price per Unit'].drop('Price per Unit')

# Select the variable with the highest correlation
variable = correlation.idxmax()

# Create scatter plot
plt.scatter(dairy_df[variable], dairy_df['Price per Unit'])
plt.xlabel(variable)
plt.ylabel('Price per Unit')
plt.title('Scatter Plot: {} vs Price per Unit'.format(variable))
plt.show()

sns.scatterplot(data=dairy_df, x='Quantity (liters/kg)', y='Approx. Total Revenue(INR)')
plt.title('Scatter Plot of Quantity vs. Approx. Total Revenue')
plt.show()

# %% [markdown]
# 7. Plotting lineplot to decipher total value trend over time

# %%
sns.lineplot(data=dairy_df, x='Date', y='Total Value')
plt.title('Line Plot of Total Value over Time')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# 8. Visualizing aggregated data with legend

# %%
# Feature engineering for EDA
dairy_df['Month'] = dairy_df['Date'].dt.month
dairy_df['Year'] = dairy_df['Date'].dt.year
# Grouping and aggregation
#Total Value by Month and Brand
monthly_brand_total = dairy_df.groupby(['Month', 'Brand'])['Total Value'].sum().reset_index()
sns.lineplot(data=monthly_brand_total, x='Month', y='Total Value', hue='Brand')
plt.title('Total Value by Month and Brand')
plt.xticks(range(1, 13))

# Move the legend to the right side
plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))
plt.show()

# %%
# Dropping month and year since EDA is done
dairy_df.drop(['Month','Year'],axis=1, inplace=True)

# %%
# Performing sanity check of the dataframe
dairy_df.head()
# Out:
#    Location  Total Land Area (acres)  Number of Cows  Farm Size       Date  \
# 0        12                   310.84              96          1 2022-02-17
# 1        13                    19.19              44          0 2021-12-01
# 2        11                   581.69              24          1 2022-02-28
# 3        12                   908.00              89          2 2019-06-09
# 5        12                    87.64              51          1 2019-01-07
#
#    Product ID  Product Name  Brand  Quantity (liters/kg)  Price per Unit  \
# 0           5             5      2             -0.962892           85.72
# 1           1             7      0              0.646515           42.61
# 2           4             9      2              0.009784           36.50
# 3           3             2      1              1.116727           26.52
# 5           6             3      8              0.322751           85.54
#
#    Total Value  Shelf Life (days)  Storage Condition Production Date  \
# 0   19064.1280                 25                  1      2021-12-27
# 1   29293.5228                 22                  4      2021-10-03
# 2   18377.0200                 30                  3      2022-01-14
# 3   21835.5072                 72                  1      2019-05-15
# 5   50803.9168                  5                  3      2019-01-03
#
#    Expiration Date  Quantity Sold (liters/kg)  Price per Unit (sold)  \
# 0             1028                          7                  82.24
# 1              948                        558                  39.24
# 2             1050                        256                  33.81
# 3              204                        601                  28.92
# 5               24                         74                  84.75
#
#    Approx. Total Revenue(INR)  Customer Location  Sales Channel  \
# 0                      575.68                  8              2
# 1                    21895.92                  7              2
# 2                     8655.36                  8              0
# 3                    17380.92                 10              0
# 5                     6271.50                  3              1
#
#    Quantity in Stock (liters/kg)  Minimum Stock Threshold (liters/kg)  \
# 0                            215                                19.55
# 1                            129                                43.17
# 2                            247                                15.10
# 3                            222                                74.50
# 5                            519                                55.60
#
#    Reorder Quantity (liters/kg)  Total Revenue (INR)
# 0                         64.03           -82.539120
# 1                        181.10            27.548016
# 2                        140.83             0.357116
# 3                         57.68            29.615613
# 5                        139.59            27.608144
